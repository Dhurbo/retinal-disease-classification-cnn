# %%
# !pip install kaggle

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0cb56be9-bdcb-4f7d-b308-13d4a47ab333" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0cb56be9-bdcb-4f7d-b308-13d4a47ab333">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# mv: cannot stat 'kaggle.json': No such file or directory

# %%
# !kaggle datasets download -d gunavenkatdoddi/eye-diseases-classification
# Out:
# Dataset URL: https://www.kaggle.com/datasets/gunavenkatdoddi/eye-diseases-classification
# License(s): ODbL-1.0
# eye-diseases-classification.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip eye-diseases-classification.zip
# Out:
# Archive:  eye-diseases-classification.zip
# replace dataset/cataract/0_left.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace dataset/cataract/103_left.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %% [markdown]
# #Feature Extraction
# ##Load the preprocessed and segmented images
# ##Implement feature extraction techniques:

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.15
)

train_generator = datagen.flow_from_directory(
    'dataset',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

validation_generator = datagen.flow_from_directory(
    'dataset',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 3586 images belonging to 4 classes.
# Found 631 images belonging to 4 classes.

# %% [markdown]
# #Train Machine Learning Models
# ##Prepare the dataset
# ##Implement the training process

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
import os

# Count the number of subdirectories in 'dataset', representing the number of classes
num_classes = len(os.listdir('dataset'))

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax') # Now num_classes is defined
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# #Integration and Validation
# ##Model Integration
# ###Load the trained model

# %%
# Define batch_size before using it
batch_size = 32  # Or any other value you prefer

# Define the number of epochs for training
epochs = 5 # Set this to the desired number of epochs

model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=epochs, # Now 'epochs' is defined
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 8
#       4 # Define the number of epochs for training
#       5 epochs = 5 # Set this to the desired number of epochs
#       7 model.fit(
# ----> 8     train_generator,
#       9     steps_per_epoch=train_generator.samples // batch_size,
#      10     epochs=epochs, # Now 'epochs' is defined
#      11     validation_data=validation_generator,
#      12     validation_steps=validation_generator.samples // batch_size
#      13 )
#
# NameError: name 'train_generator' is not defined
